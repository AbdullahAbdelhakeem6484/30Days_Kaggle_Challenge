# %%
################################################################
#  Team Members :
#                 1-Abdullah Abdelhakeem 
#                 2-Mohamed Sebaie
#                 3-Mohamed Mostafa
#                 
#  
#  Version: v1.0.0
#  Description: 30 Days of ML
#  Day: 20/8/2021
#  
#  
###############################################################

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import VarianceThreshold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Read CSV Files

# %%
# df_train = pd.read_csv("../input/30-days-of-ml/train.csv")
# df_test = pd.read_csv("../input/30-days-of-ml/test.csv")

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %% [markdown]
# # Check Info about Data

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 26 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      300000 non-null  int64
#  1   cat0    300000 non-null  object
#  2   cat1    300000 non-null  object
#  3   cat2    300000 non-null  object
#  4   cat3    300000 non-null  object
#  5   cat4    300000 non-null  object
#  6   cat5    300000 non-null  object
#  7   cat6    300000 non-null  object
#  8   cat7    300000 non-null  object
#  9   cat8    300000 non-null  object
#  10  cat9    300000 non-null  object
#  11  cont0   300000 non-null  float64
#  12  cont1   300000 non-null  float64
#  13  cont2   300000 non-null  float64
#  14  cont3   300000 non-null  float64
#  15  cont4   300000 non-null  float64
#  16  cont5   300000 non-null  float64
#  17  cont6   300000 non-null  float64
#  18  cont7   300000 non-null  float64
#  19  cont8   300000 non-null  float64
#  20  cont9   300000 non-null  float64
#  21  cont10  300000 non-null  float64
#  22  cont11  300000 non-null  float64
#  23  cont12  300000 non-null  float64
#  24  cont13  300000 non-null  float64
#  25  target  300000 non-null  float64
# dtypes: float64(15), int64(1), object(10)
# memory usage: 59.5+ MB

# %%
df_train.describe()
# Out:
#                   id          cont0          cont1          cont2  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   250018.576947       0.527335       0.460926       0.490498
# std    144450.150010       0.230599       0.214003       0.253346
# min         1.000000      -0.118039      -0.069309      -0.056104
# 25%    124772.500000       0.405965       0.310494       0.300604
# 50%    250002.500000       0.497053       0.427903       0.502462
# 75%    375226.500000       0.668060       0.615113       0.647512
# max    499999.000000       1.058443       0.887253       1.034704
#
#                cont3          cont4          cont5          cont6  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.496689       0.491654       0.510526       0.467476
# std         0.219199       0.240074       0.228232       0.210331
# min         0.130676       0.255908       0.045915      -0.224689
# 25%         0.329783       0.284188       0.354141       0.342873
# 50%         0.465026       0.390470       0.488865       0.429383
# 75%         0.664451       0.696599       0.669625       0.573383
# max         1.039560       1.055424       1.067649       1.111552
#
#                cont7          cont8          cont9         cont10  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.537119       0.498456       0.474872       0.474492
# std         0.218140       0.239920       0.218007       0.255949
# min         0.203763      -0.260275       0.117896       0.048732
# 25%         0.355825       0.332486       0.306874       0.276017
# 50%         0.504661       0.439151       0.434620       0.459975
# 75%         0.703441       0.606056       0.614333       0.691579
# max         1.032837       1.040229       0.982922       1.055960
#
#               cont11         cont12         cont13         target
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.473216       0.494561       0.508273       8.241979
# std         0.222022       0.247292       0.222950       0.746555
# min         0.052608      -0.074208       0.151050       0.140329
# 25%         0.308151       0.289074       0.300669       7.742071
# 50%         0.433812       0.422887       0.472400       8.191373
# 75%         0.642057       0.714502       0.758447       8.728634
# max         1.071444       0.975035       0.905992      10.411992

# %%
df_train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Check Quantitative and Qualitative Columns

# %%
quantitative = [f for f in df_train.columns if df_train.dtypes[f] != object]
qualitative = [f for f in df_train.columns if df_train.dtypes[f] == object]

# %% [markdown]
# # Check Data Distribution

# %%
df_train[quantitative].hist(bins = 50, figsize = (20,15))
plt.show()

# %% [markdown]
# # Check correlation between Variables

# %%
correlation_matrix = df_train[quantitative].corr()
correlation_matrix["target"].sort_values(ascending = False)
correlation_matrix
# Out:
#            cont0     cont1     cont2     cont3     cont4     cont5     cont6  \
# cont0   1.000000 -0.009422 -0.296989  0.211333 -0.109776  0.392456  0.133995
# cont1  -0.009422  1.000000 -0.000627 -0.002233 -0.000285  0.003812  0.001321
# cont2  -0.296989 -0.000627  1.000000 -0.180856  0.092780 -0.300140 -0.141724
# cont3   0.211333 -0.002233 -0.180856  1.000000 -0.069934  0.201441  0.040133
# cont4  -0.109776 -0.000285  0.092780 -0.069934  1.000000 -0.148807 -0.044417
# cont5   0.392456  0.003812 -0.300140  0.201441 -0.148807  1.000000  0.211800
# cont6   0.133995  0.001321 -0.141724  0.040133 -0.044417  0.211800  1.000000
# cont7   0.294687  0.013475 -0.283989  0.172586 -0.095653  0.329357  0.135333
# cont8   0.388510 -0.021541 -0.326456  0.185221 -0.122594  0.392057  0.117833
# cont9   0.394969 -0.002727 -0.309118  0.194807 -0.123468  0.411366  0.187303
# cont10  0.363413 -0.001648 -0.300273  0.199525 -0.132211  0.402053  0.178168
# cont11  0.255941 -0.017221 -0.325023  0.140934 -0.115173  0.308249  0.168731
# cont12  0.417872 -0.006862 -0.352009  0.255117 -0.151080  0.473964  0.171010
# cont13  0.023234 -0.010097 -0.039815  0.037920 -0.012798  0.053779  0.031183
# target  0.028819 -0.002096  0.034280 -0.022759 -0.023132 -0.015058 -0.013807
#
#            cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# cont0   0.294687  0.388510  0.394969  0.363413  0.255941  0.417872  0.023234
# cont1   0.013475 -0.021541 -0.002727 -0.001648 -0.017221 -0.006862 -0.010097
# cont2  -0.283989 -0.326456 -0.309118 -0.300273 -0.325023 -0.352009 -0.039815
# cont3   0.172586  0.185221  0.194807  0.199525  0.140934  0.255117  0.037920
# cont4  -0.095653 -0.122594 -0.123468 -0.132211 -0.115173 -0.151080 -0.012798
# cont5   0.329357  0.392057  0.411366  0.402053  0.308249  0.473964  0.053779
# cont6   0.135333  0.117833  0.187303  0.178168  0.168731  0.171010  0.031183
# cont7   1.000000  0.332639  0.320239  0.283414  0.279405  0.363091  0.056958
# cont8   0.332639  1.000000  0.406517  0.341430  0.297121  0.434196  0.050163
# cont9   0.320239  0.406517  1.000000  0.361941  0.327866  0.437776  0.044631
# cont10  0.283414  0.341430  0.361941  1.000000  0.293860  0.407609  0.041353
# cont11  0.279405  0.297121  0.327866  0.293860  1.000000  0.363579  0.031141
# cont12  0.363091  0.434196  0.437776  0.407609  0.363579  1.000000  0.059919
# cont13  0.056958  0.050163  0.044631  0.041353  0.031141  0.059919  1.000000
# target  0.035143  0.017740 -0.015726  0.052468  0.033378  0.055829 -0.028189
#
#           target
# cont0   0.028819
# cont1  -0.002096
# cont2   0.034280
# cont3  -0.022759
# cont4  -0.023132
# cont5  -0.015058
# cont6  -0.013807
# cont7   0.035143
# cont8   0.017740
# cont9  -0.015726
# cont10  0.052468
# cont11  0.033378
# cont12  0.055829
# cont13 -0.028189
# target  1.000000

# %%
mask = np.array(correlation_matrix)
mask[np.tril_indices_from(mask)] = False
fig = plt.figure(figsize=(18, 10))
sns.heatmap(correlation_matrix, mask=mask, annot=True, cbar=True, vmax=0.8, vmin=-0.8, cmap='RdYlGn')
plt.title('Correlation Map')
plt.show()

# %%
correlation_matrix["target"].sort_values(ascending = False)
# Out:
# target    1.000000
# cont12    0.055829
# cont10    0.052468
# cont7     0.035143
# cont2     0.034280
# cont11    0.033378
# cont0     0.028819
# cont8     0.017740
# cont1    -0.002096
# cont6    -0.013807
# cont5    -0.015058
# cont9    -0.015726
# cont3    -0.022759
# cont4    -0.023132
# cont13   -0.028189
# Name: target, dtype: float64

# %%
df_train.drop(columns = 'id',inplace = True)
df_test_modified = df_test.drop(columns = 'id',inplace =False)

# %%
quantitative.remove('id')
quantitative
# Out:
# ['cont0',
#  'cont1',
#  'cont2',
#  'cont3',
#  'cont4',
#  'cont5',
#  'cont6',
#  'cont7',
#  'cont8',
#  'cont9',
#  'cont10',
#  'cont11',
#  'cont12',
#  'cont13',
#  'target']

# %% [markdown]
# # Encoding Qualitative Data

# %%
from sklearn.preprocessing import LabelEncoder
df_train[qualitative] = df_train[qualitative].apply(LabelEncoder().fit_transform)
df_test_modified[qualitative] = df_test_modified[qualitative].apply(LabelEncoder().fit_transform)

# %%
df_train
# Out:
#         cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...  \
# 0          1     1     1     2     1     1     0     4     2    13  ...
# 1          1     1     0     0     1     3     0     5     0    14  ...
# 2          0     0     0     2     1     3     0     3     0     5  ...
# 3          1     1     0     2     1     3     0     4     2    10  ...
# 4          0     0     0     2     1     3     0     4     0    13  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 299995     1     1     0     0     1     3     0     4     0     8  ...
# 299996     0     1     0     2     1     1     0     4     4     5  ...
# 299997     1     1     0     2     1     2     0     4     6     5  ...
# 299998     0     1     0     2     1     1     0     4     4     8  ...
# 299999     0     0     0     2     0     3     0     4     0    14  ...
#
#            cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# 0       0.400361  0.160266  0.310921  0.389470  0.267559  0.237281  0.377873
# 1       0.533087  0.558922  0.516294  0.594928  0.341439  0.906013  0.921701
# 2       0.650609  0.375348  0.902567  0.555205  0.843531  0.748809  0.620126
# 3       0.668980  0.239061  0.732948  0.679618  0.574844  0.346010  0.714610
# 4       0.686964  0.420667  0.648182  0.684501  0.956692  1.000773  0.776742
# ...          ...       ...       ...       ...       ...       ...       ...
# 299995  0.769792  0.450538  0.934360  1.005077  0.853726  0.422541  1.063463
# 299996  0.528056  0.508502  0.358247  0.257825  0.433525  0.301015  0.268447
# 299997  0.688747  0.372425  0.364936  0.383224  0.551825  0.661007  0.629606
# 299998  0.344404  0.424243  0.382028  0.468819  0.351036  0.288768  0.611169
# 299999  0.565347  0.328669  0.789165  0.960406  0.776019  0.734707  0.484392
#
#           cont12    cont13    target
# 0       0.322401  0.869850  8.113634
# 1       0.261975  0.465083  8.481233
# 2       0.541474  0.763846  8.364351
# 3       0.540150  0.280682  8.049253
# 4       0.625849  0.250823  7.972260
# ...          ...       ...       ...
# 299995  0.697685  0.506404  7.945605
# 299996  0.577055  0.823611  7.326118
# 299997  0.714139  0.245732  8.706755
# 299998  0.380254  0.332030  7.229569
# 299999  0.639754  0.689317  8.631146
#
# [300000 rows x 25 columns]

# %% [markdown]
# # Modelling

# %%
df_train.columns
# Out:
# Index(['cat0', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8',
#        'cat9', 'cont0', 'cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6',
#        'cont7', 'cont8', 'cont9', 'cont10', 'cont11', 'cont12', 'cont13',
#        'target'],
#       dtype='object')

# %%
train_df, val_df = train_test_split(df_train, test_size=0.2, random_state=20)
X_train = train_df.drop(columns = 'target')
y_train = train_df['target']
X_val = val_df.drop(columns = 'target')
y_val = val_df['target']
X_test = df_test_modified

# %%
print(f"No of Records (Original Data): {len(df_train)}\nNo of Records (train_df): {len(train_df)}\nNo of Records (val_df) {len(val_df)}")
# Out:
# No of Records (Original Data): 300000
# No of Records (train_df): 240000
# No of Records (val_df) 60000

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, PoissonRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.ensemble import BaggingRegressor
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import r2_score

# %%
models = {
    "LinearRegression":            LinearRegression(),
    "Ridge":                       Ridge(),
    "Lasso":                       Lasso(),
    "ElasticNet":                  ElasticNet(),
#     "KNeighborsRegressor":         KNeighborsRegressor(), 
#     "DecisionTreeRegressor":       DecisionTreeRegressor(),
#     "RandomForestRegressor":       RandomForestRegressor(),
#     "BaggingRegressor":            BaggingRegressor(),
#     "AdaBoostRegressor":           AdaBoostRegressor(),
    "CatBoostRegressor":           CatBoostRegressor(verbose=False),
    "LGBMRegressor":               LGBMRegressor(),
#     "GradientBoostingRegressor":   GradientBoostingRegressor(),
    "XGBRegressor":                XGBRegressor()
}

# %%
for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(X_train, y_train)
    print(f"train score : {model.score(X_train,y_train)}")
    print(f'RMSLETrain: { np.sqrt(mean_squared_error(y_train, model.predict(X_train)))}')
    print(f'RMSLEVal: { np.sqrt(mean_squared_error(y_val, model.predict(X_val)))}')
    print('-'*30)
# Out:
# Using model: LinearRegression
# train score : 0.019612419677495052
# RMSLETrain: 0.7403353497454035
# RMSLEVal: 0.7344606055979458
# ------------------------------
# Using model: Ridge
# train score : 0.019612419428624572
# RMSLETrain: 0.7403353498393703
# RMSLEVal: 0.7344606225020776
# ------------------------------
# Using model: Lasso
# train score : 0.0
# RMSLETrain: 0.7477037972490317
# RMSLEVal: 0.7419349666768976
# ------------------------------
# Using model: ElasticNet
# train score : 0.0
# RMSLETrain: 0.7477037972490317
# RMSLEVal: 0.7419349666768976
# ------------------------------
# Using model: CatBoostRegressor
# train score : 0.12330659818223932
# RMSLETrain: 0.7000893244638187
# RMSLEVal: 0.7167129264877417
# ------------------------------
# Using model: LGBMRegressor
# train score : 0.0778886712112491
# RMSLETrain: 0.7179947440366572
# RMSLEVal: 0.7204148742210911
# ------------------------------
# Using model: XGBRegressor
# train score : 0.1510450414033292
# RMSLETrain: 0.6889249460562036
# RMSLEVal: 0.7207491975110487
# ------------------------------

# %% [markdown]
# ## Test Model and Submit file

# %%
# grid = {'learning_rate': [0.03, 0.1],
#         'depth': [4, 6, 10],
#         'l2_leaf_reg': [1, 3, 5, 7, 9]}
# model=CatBoostRegressor(verbose=False)
# grid_search_result = model.grid_search(grid, 
#                                        X=X_train, 
#                                        y=y_train, 
#                                        plot=True)
# Out:
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# bestTest = 0.729639996
# bestIteration = 999
#
# 0:	loss: 0.7296400	best: 0.7296400 (0)	total: 33.3s	remaining: 16m 5s
#
# bestTest = 0.7245099245
# bestIteration = 990
#
# 1:	loss: 0.7245099	best: 0.7245099 (1)	total: 1m 4s	remaining: 14m 59s
#
# bestTest = 0.7296076948
# bestIteration = 999
#
# 2:	loss: 0.7296077	best: 0.7245099 (1)	total: 1m 32s	remaining: 13m 55s
#
# bestTest = 0.7242913048
# bestIteration = 986
#
# 3:	loss: 0.7242913	best: 0.7242913 (3)	total: 2m 1s	remaining: 13m 11s
#
# bestTest = 0.7296095344
# bestIteration = 999
#
# 4:	loss: 0.7296095	best: 0.7242913 (3)	total: 2m 30s	remaining: 12m 34s
#
# bestTest = 0.7245550435
# bestIteration = 999
#
# 5:	loss: 0.7245550	best: 0.7242913 (3)	total: 3m	remaining: 12m 1s
#
# bestTest = 0.7296720265
# bestIteration = 999
#
# 6:	loss: 0.7296720	best: 0.7242913 (3)	total: 3m 29s	remaining: 11m 28s
#
# bestTest = 0.7246119884
# bestIteration = 999
#
# 7:	loss: 0.7246120	best: 0.7242913 (3)	total: 4m 5s	remaining: 11m 15s
#
# bestTest = 0.7297083919
# bestIteration = 999
#
# 8:	loss: 0.7297084	best: 0.7242913 (3)	total: 4m 40s	remaining: 10m 53s
#
# bestTest = 0.7244785074
# bestIteration = 999
#
# 9:	loss: 0.7244785	best: 0.7242913 (3)	total: 5m 13s	remaining: 10m 26s
#
# bestTest = 0.7276667369
# bestIteration = 999
#
# 10:	loss: 0.7276667	best: 0.7242913 (3)	total: 5m 52s	remaining: 10m 9s
#
# bestTest = 0.7250467423
# bestIteration = 998
#
# 11:	loss: 0.7250467	best: 0.7242913 (3)	total: 6m 31s	remaining: 9m 46s
#
# bestTest = 0.7278103223
# bestIteration = 998
#
# 12:	loss: 0.7278103	best: 0.7242913 (3)	total: 7m 11s	remaining: 9m 24s
#
# bestTest = 0.725163513
# bestIteration = 902
#
# 13:	loss: 0.7251635	best: 0.7242913 (3)	total: 7m 51s	remaining: 8m 58s
#
# bestTest = 0.7278511681
# bestIteration = 999
#
# 14:	loss: 0.7278512	best: 0.7242913 (3)	total: 8m 30s	remaining: 8m 30s
#
# bestTest = 0.7249719252
# bestIteration = 998
#
# 15:	loss: 0.7249719	best: 0.7242913 (3)	total: 9m 9s	remaining: 8m
#
# bestTest = 0.7279117172
# bestIteration = 999
#
# 16:	loss: 0.7279117	best: 0.7242913 (3)	total: 9m 48s	remaining: 7m 30s
#
# bestTest = 0.7251155846
# bestIteration = 902
#
# 17:	loss: 0.7251156	best: 0.7242913 (3)	total: 10m 27s	remaining: 6m 58s
#
# bestTest = 0.7279816765
# bestIteration = 999
#
# 18:	loss: 0.7279817	best: 0.7242913 (3)	total: 11m 6s	remaining: 6m 25s
#
# bestTest = 0.725020201
# bestIteration = 936
#
# 19:	loss: 0.7250202	best: 0.7242913 (3)	total: 11m 44s	remaining: 5m 52s
#
# bestTest = 0.7276416478
# bestIteration = 999
#
# 20:	loss: 0.7276416	best: 0.7242913 (3)	total: 14m 3s	remaining: 6m 1s
#
# bestTest = 0.7289671368
# bestIteration = 359
#
# 21:	loss: 0.7289671	best: 0.7242913 (3)	total: 16m 23s	remaining: 5m 57s
#
# bestTest = 0.7280919384
# bestIteration = 999
#
# 22:	loss: 0.7280919	best: 0.7242913 (3)	total: 19m	remaining: 5m 47s
#
# bestTest = 0.7290727506
# bestIteration = 463
#
# 23:	loss: 0.7290728	best: 0.7242913 (3)	total: 21m 38s	remaining: 5m 24s
#
# bestTest = 0.7279464608
# bestIteration = 999
#
# 24:	loss: 0.7279465	best: 0.7242913 (3)	total: 24m 12s	remaining: 4m 50s
#
# bestTest = 0.7293972442
# bestIteration = 399
#
# 25:	loss: 0.7293972	best: 0.7242913 (3)	total: 26m 38s	remaining: 4m 5s
#
# bestTest = 0.72828951
# bestIteration = 998
#
# 26:	loss: 0.7282895	best: 0.7242913 (3)	total: 28m 54s	remaining: 3m 12s
#
# bestTest = 0.72881062
# bestIteration = 495
#
# 27:	loss: 0.7288106	best: 0.7242913 (3)	total: 31m 7s	remaining: 2m 13s
#
# bestTest = 0.7282846494
# bestIteration = 999
#
# 28:	loss: 0.7282846	best: 0.7242913 (3)	total: 33m 16s	remaining: 1m 8s
#
# bestTest = 0.7293328475
# bestIteration = 403
#
# 29:	loss: 0.7293328	best: 0.7242913 (3)	total: 35m 28s	remaining: 0us
# Estimating final quality...

# %%
# Model=CatBoostRegressor(verbose=False,n_estimators=400,learning_rate=0.02)
# Model=XGBRegressor(learning_rate = 0.5 ,random_state = 42)
# Model=LGBMRegressor()---> 0.72644 in kaggle
Model=BaggingRegressor(CatBoostRegressor(verbose=False, learning_rate=0.2,depth=6))
Model.fit(X_train, y_train)
print(f'RMSLETrain: { np.sqrt(mean_squared_error(y_train, Model.predict(X_train)))}')
print(f'RMSLEVal: { np.sqrt(mean_squared_error(y_val, Model.predict(X_val)))}')
# Out:
# RMSLETrain: 0.6775277313706566
# RMSLEVal: 0.717259025656848

# %%
y_test_predicted = Model.predict(X_test)
output = pd.DataFrame({'id': df_test['id'], 'target': y_test_predicted})
output.to_csv('my_submission.csv', index=False)

# %%
output
# Out:
#             id    target
# 0            0  8.054987
# 1            5  8.322727
# 2           15  8.424140
# 3           16  8.499834
# 4           17  8.204022
# ...        ...       ...
# 199995  499987  8.059212
# 199996  499990  8.429891
# 199997  499991  8.462999
# 199998  499994  8.209142
# 199999  499995  8.052890
#
# [200000 rows x 2 columns]
